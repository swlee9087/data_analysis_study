# %%
# REF https://thecleverprogrammer.com/2021/08/09/social-media-followers-prediction-with-machine-learning/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("stats.csv")
data.drop(data.tail(1).index, inplace=True)
data
# Out:
#    period_start  period_end  followers_gained  followers_lost  followers_net  \
# 0      5/1/2020   5/31/2020                 1               0              1
# 1      6/1/2020   6/30/2020                 8               0              8
# 2      7/1/2020   7/31/2020               103               0            103
# 3      8/1/2020   8/31/2020                46               0             46
# 4      9/1/2020   9/30/2020                35               1             34
# 5     10/1/2020  10/31/2020                30               0             30
# 6     11/1/2020  11/30/2020               311               1            310
# 7     12/1/2020  12/31/2020               217               0            217
# 8      1/1/2021   1/31/2021               826               1            825
# 9      2/1/2021   2/28/2021               394               1            393
# 10     3/1/2021   3/31/2021               390               2            388
# 11     4/1/2021   4/30/2021               454               2            452
# 12     5/1/2021   5/31/2021               462               7            455
# 13     6/1/2021   6/30/2021               595               3            592
# 14     7/1/2021   7/31/2021               541               5            536
#
#     followers_total  subscribers_gained  subscribers_lost  subscribers_net  \
# 0                 1                   0                 0                0
# 1                 9                   0                 0                0
# 2               112                   0                 0                0
# 3               158                   0                 0                0
# 4               192                   0                 0                0
# 5               222                   0                 0                0
# 6               532                   3                 0                3
# 7               749                  10                 1                9
# 8              1574                  14                 1               13
# 9              1967                   7                 0                7
# 10             2355                   7                 2                5
# 11             2807                   8                 0                8
# 12             3262                   6                 0                6
# 13             3854                   5                 0                5
# 14             4390                  20                 6               14
#
#     subscribers_total     views
# 0                   0     128.0
# 1                   0   16130.0
# 2                   0   14616.0
# 3                   0    4053.0
# 4                   0    5153.0
# 5                   0   16029.0
# 6                   3   59976.0
# 7                  12   76322.0
# 8                  25  108962.0
# 9                  32  100650.0
# 10                 37  102987.0
# 11                 45  134765.0
# 12                 51  167608.0
# 13                 56  154235.0
# 14                 70  144167.0

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Number of Followers Gained Every Month")
sns.barplot(x="followers_gained", y="period_end", data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Followers At The End of Every Month")
sns.barplot(x="followers_total", y="period_end", data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Views Every Month")
sns.barplot(x="views", y="period_end", data=data)
plt.show()

# %%
# !pip install autots
# Out:
# Collecting autots
#   Downloading AutoTS-0.5.1-py3-none-any.whl (672 kB)
#      -------------------------------------- 672.4/672.4 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.10.* in d:\anaconda3\envs\sd_env\lib\site-packages (from autots) (0.13.5)
# Requirement already satisfied: numpy>=1.14.6 in d:\anaconda3\envs\sd_env\lib\site-packages (from autots) (1.21.6)
# Requirement already satisfied: pandas>=0.25.* in d:\anaconda3\envs\sd_env\lib\site-packages (from autots) (1.2.3)
# Requirement already satisfied: scikit-learn>=0.20.* in d:\anaconda3\envs\sd_env\lib\site-packages (from autots) (1.0.2)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda3\envs\sd_env\lib\site-packages (from pandas>=0.25.*->autots) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda3\envs\sd_env\lib\site-packages (from pandas>=0.25.*->autots) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\envs\sd_env\lib\site-packages (from scikit-learn>=0.20.*->autots) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in d:\anaconda3\envs\sd_env\lib\site-packages (from scikit-learn>=0.20.*->autots) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\envs\sd_env\lib\site-packages (from scikit-learn>=0.20.*->autots) (1.1.0)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\envs\sd_env\lib\site-packages (from statsmodels>=0.10.*->autots) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in d:\anaconda3\envs\sd_env\lib\site-packages (from statsmodels>=0.10.*->autots) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\sd_env\lib\site-packages (from packaging>=21.3->statsmodels>=0.10.*->autots) (3.0.9)
# Requirement already satisfied: six in d:\anaconda3\envs\sd_env\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.10.*->autots) (1.16.0)
# Installing collected packages: autots
# Successfully installed autots-0.5.1

# %%
from autots import AutoTS
model = AutoTS(forecast_length=4, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='period_end', value_col='followers_gained', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Inferred frequency is: M
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model ARIMA in generation 0 of 10
# Model Number: 3 with model ARIMA in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model AverageValueNaive in generation 0 of 10
# Model Number: 6 with model AverageValueNaive in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Model Number: 9 with model DatepartRegression in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# Model Number: 10 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.3676
# Epoch 2/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3768
# Epoch 3/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3675
# Epoch 4/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3665
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3587
# Epoch 6/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3633
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3659
# Epoch 8/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3596
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3549
# Epoch 10/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3627
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3585
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3509
# Epoch 13/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3577
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3547
# Epoch 15/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3512
# Epoch 16/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3440
# Epoch 17/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3469
# Epoch 18/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3570
# Epoch 19/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3534
# Epoch 20/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3475
# Epoch 21/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3543
# Epoch 22/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3426
# Epoch 23/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3390
# Epoch 24/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3294
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3457
# Epoch 26/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3405
# Epoch 27/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3341
# Epoch 28/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3598
# Epoch 29/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3293
# Epoch 30/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3427
# Epoch 31/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3373
# Epoch 32/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3267
# Epoch 33/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3246
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3267
# Epoch 35/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3326
# Epoch 36/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3140
# Epoch 37/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3365
# Epoch 38/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3223
# Epoch 39/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3222
# Epoch 40/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3110
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3228
# Epoch 42/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3362
# Epoch 43/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3161
# Epoch 44/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3174
# Epoch 45/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2948
# Epoch 46/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3026
# Epoch 47/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2891
# Epoch 48/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3140
# Epoch 49/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3028
# Epoch 50/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2773
# 1/1 [==============================] - 1s 777ms/step
# Model Number: 11 with model ETS in generation 0 of 10
# Model Number: 12 with model ETS in generation 0 of 10
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on followers_gained with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 13 with model GLM in generation 0 of 10
# Template Eval Error: PerfectSeparationError('Perfect separation detected, results not available') in model 13: GLM
# Model Number: 14 with model GLM in generation 0 of 10
# Model Number: 15 with model GLS in generation 0 of 10
# Model Number: 16 with model GLS in generation 0 of 10
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 20: GluonTS
# Model Number: 21 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 21: GluonTS
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model LastValueNaive in generation 0 of 10
# Model Number: 25 with model LastValueNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model SeasonalNaive in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model UnobservedComponents in generation 0 of 10
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 36: WindowRegression
# Model Number: 37 with model ConstantNaive in generation 0 of 10
# Model Number: 38 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 38: FBProphet
# Model Number: 39 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 39: GluonTS
# Model Number: 40 with model MultivariateRegression in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 41 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 41: MultivariateRegression
# Model Number: 42 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 42: DatepartRegression
# Model Number: 43 with model SeasonalNaive in generation 0 of 10
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 44 with model DatepartRegression in generation 0 of 10
# Model Number: 45 with model UnobservedComponents in generation 0 of 10
# Model Number: 46 with model UnobservedComponents in generation 0 of 10
# Model Number: 47 with model ETS in generation 0 of 10
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on followers_gained with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 48 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 48: VECM
# Model Number: 49 with model ARDL in generation 0 of 10
# Model Number: 50 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 50: MultivariateMotif
# Model Number: 51 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 51: MultivariateMotif
# Model Number: 52 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 52: UnivariateMotif
# Model Number: 53 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 53: UnivariateMotif
# Model Number: 54 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation fmax which has no identity') in model 54: SectionalMotif
# Model Number: 55 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (3)') in model 55: SectionalMotif
# Model Number: 56 with model MultivariateRegression in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\core\_methods.py:182: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# Model Number: 57 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 57: FBProphet
# Model Number: 58 with model SeasonalNaive in generation 0 of 10
# Model Number: 59 with model DatepartRegression in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 60 with model NVAR in generation 0 of 10
# Model Number: 61 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 61: Theta
# Model Number: 62 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 62: UnivariateRegression
# Model Number: 63 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 63: ARCH
# Model Number: 64 with model ConstantNaive in generation 0 of 10
# Model Number: 65 with model LastValueNaive in generation 0 of 10
# Model Number: 66 with model AverageValueNaive in generation 0 of 10
# Model Number: 67 with model GLS in generation 0 of 10
# Model Number: 68 with model SeasonalNaive in generation 0 of 10
# Model Number: 69 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 69: GLM
# Model Number: 70 with model ETS in generation 0 of 10
# Model Number: 71 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 71: FBProphet
# Model Number: 72 with model GluonTS in generation 0 of 10
# Template Eval Error: Exception('Transformer STLFilter failed on fit') in model 72: GluonTS
# Model Number: 73 with model UnobservedComponents in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:177: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 74 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 74: VAR
# Model Number: 75 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 75: VECM
# Model Number: 76 with model ARIMA in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 76: ARIMA
# Model Number: 77 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 77: WindowRegression
# Model Number: 78 with model DatepartRegression in generation 0 of 10
# Model Number: 79 with model UnivariateRegression in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\experimental\enable_hist_gradient_boosting.py:17: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   "Since version 1.0, "
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 80 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 80: MultivariateRegression
# Model Number: 81 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 81: UnivariateMotif
# Model Number: 82 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 82: MultivariateMotif
# Model Number: 83 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation fmax which has no identity') in model 83: SectionalMotif
# Model Number: 84 with model NVAR in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Model Number: 85 with model Theta in generation 0 of 10
# Model Number: 86 with model ARDL in generation 0 of 10
# Model Number: 87 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 87: ARCH
# Model Number: 88 with model MetricMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=99) out of bounds (3)') in model 88: MetricMotif
# Model Number: 89 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=9) out of bounds (3)') in model 89: SeasonalityMotif
# Model Number: 90 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 90: UnivariateRegression
# Model Number: 91 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 91: GluonTS
# Model Number: 92 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 92: MultivariateRegression
# Model Number: 93 with model GLM in generation 0 of 10
# Model Number: 94 with model SeasonalNaive in generation 0 of 10
# Model Number: 95 with model GLS in generation 0 of 10
# Model Number: 96 with model MetricMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=19) out of bounds (3)') in model 96: MetricMotif
# Model Number: 97 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 97: GLM
# Model Number: 98 with model MetricMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 98: MetricMotif
# Model Number: 99 with model SeasonalityMotif in generation 0 of 10
# Model Number: 100 with model ConstantNaive in generation 0 of 10
# Model Number: 101 with model ConstantNaive in generation 0 of 10
# Model Number: 102 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 102: GluonTS
# Model Number: 103 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 103: ARDL
# Model Number: 104 with model ConstantNaive in generation 0 of 10
# Model Number: 105 with model VAR in generation 0 of 10
# Template Eval Error: Exception('Transformer ScipyFilter failed on fit') in model 105: VAR
# Model Number: 106 with model GLS in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1346: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# Model Number: 107 with model GLS in generation 0 of 10
# Model Number: 108 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 108: MultivariateMotif
# Model Number: 109 with model AverageValueNaive in generation 0 of 10
# Model Number: 110 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 110: SectionalMotif
# Model Number: 111 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 111: SeasonalityMotif
# Model Number: 112 with model GLM in generation 0 of 10
# Model Number: 113 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 113: VECM
# Model Number: 114 with model UnobservedComponents in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1342: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# Model Number: 115 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 115: SeasonalityMotif
# Model Number: 116 with model WindowRegression in generation 0 of 10
# Model Number: 117 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 117: ARCH
# Model Number: 118 with model MetricMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=14) out of bounds (3)') in model 118: MetricMotif
# Model Number: 119 with model GLM in generation 0 of 10
# Model Number: 120 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 120: GluonTS
# Model Number: 121 with model LastValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on fit') in model 121: LastValueNaive
# Model Number: 122 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 122: UnobservedComponents
# Model Number: 123 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 123: ARDL
# Model Number: 124 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 124: UnivariateRegression
# Model Number: 125 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 125: MultivariateMotif
# Model Number: 126 with model MetricMotif in generation 0 of 10
# Model Number: 127 with model ConstantNaive in generation 0 of 10
# Model Number: 128 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 128: ARDL
# Model Number: 129 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 129: SectionalMotif
# Model Number: 130 with model LastValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on fit') in model 130: LastValueNaive
# Model Number: 131 with model MetricMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on fit') in model 131: MetricMotif
# Model Number: 132 with model GLM in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 132: GLM
# Model Number: 133 with model MetricMotif in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\window_functions.py:478: RuntimeWarning: invalid value encountered in true_divide
#   slope = (sxy - sx * sy) / (sx2 - sx**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\nanfunctions.py:1376: RuntimeWarning: All-NaN slice encountered
#   overwrite_input=overwrite_input, interpolation=interpolation
# Template Eval Error: ValueError('kth(=19) out of bounds (3)') in model 133: MetricMotif
# Model Number: 134 with model UnivariateMotif in generation 0 of 10
# No anomalies detected.
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 134: UnivariateMotif
# Model Number: 135 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 135: MultivariateMotif
# Model Number: 136 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 136: VECM
# Model Number: 137 with model GLS in generation 0 of 10
# Model Number: 138 with model ARCH in generation 0 of 10
# No anomalies detected.
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 138: ARCH
# Model Number: 139 with model ARCH in generation 0 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 139: ARCH
# Model Number: 140 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: Exception('Transformer ScipyFilter failed on fit') in model 140: UnobservedComponents
# Model Number: 141 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 141: ARCH
# Model Number: 142 with model Theta in generation 0 of 10
# Model Number: 143 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 24 observations. x only has 11 observation(s)') in model 143: Theta
# Model Number: 144 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 144: MultivariateRegression
# Model Number: 145 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 145: UnivariateMotif
# Model Number: 146 with model Theta in generation 0 of 10
# Model Number: 147 with model ETS in generation 0 of 10
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on followers_gained with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 148 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 148: MultivariateMotif
# Model Number: 149 with model ConstantNaive in generation 0 of 10
# Model Number: 150 with model SeasonalNaive in generation 0 of 10
# Model Number: 151 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 151: SectionalMotif
# Model Number: 152 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 152: GLM
# Model Number: 153 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 153: ARCH
# Model Number: 154 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 154: VECM
# Model Number: 155 with model Theta in generation 0 of 10
# Model Number: 156 with model MultivariateRegression in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 156: MultivariateRegression
# Model Number: 157 with model NVAR in generation 0 of 10
# Model Number: 158 with model UnobservedComponents in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\neighbors\_regression.py:470: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 159 with model MetricMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 159: MetricMotif
# Model Number: 160 with model UnobservedComponents in generation 0 of 10
# Model Number: 161 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 161: SeasonalityMotif
# Model Number: 162 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 162: SectionalMotif
# Model Number: 163 with model ARCH in generation 0 of 10
# Template Eval Error: Exception('Transformer ScipyFilter failed on fit') in model 163: ARCH
# Model Number: 164 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=9) out of bounds (1)') in model 164: SeasonalityMotif
# Model Number: 165 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 165: SeasonalityMotif
# Model Number: 166 with model NVAR in generation 0 of 10
# Model Number: 167 with model DatepartRegression in generation 0 of 10
# Model Number: 168 with model UnobservedComponents in generation 0 of 10
# Model Number: 169 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 169: ARCH
# Model Number: 170 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 170: UnivariateMotif
# Model Number: 171 with model AverageValueNaive in generation 0 of 10
# Model Number: 172 with model ConstantNaive in generation 0 of 10
# Model Number: 173 with model LastValueNaive in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 174 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 174: UnivariateRegression
# Model Number: 175 with model MetricMotif in generation 0 of 10
# No anomalies detected.
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 175: MetricMotif
# Model Number: 176 with model MultivariateRegression in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\window_functions.py:478: RuntimeWarning: invalid value encountered in true_divide
#   slope = (sxy - sx * sy) / (sx2 - sx**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\preprocessing\_data.py:1187: RuntimeWarning: All-NaN slice encountered
#   max_abs = np.nanmax(np.abs(X), axis=0)
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\utils\extmath.py:985: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\utils\extmath.py:990: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\utils\extmath.py:1020: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 436 tasks      | elapsed:    0.2s
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 176: MultivariateRegression
# Model Number: 177 with model GLM in generation 0 of 10
# Template Eval Error: PerfectSeparationError('Perfect separation detected, results not available') in model 177: GLM
# Model Number: 178 with model ConstantNaive in generation 0 of 10
# [Parallel(n_jobs=-2)]: Done 786 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done 1000 out of 1000 | elapsed:    0.6s finished
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# Model Number: 179 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer ScipyFilter failed on fit') in model 179: MultivariateMotif
# Model Number: 180 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 180: SeasonalityMotif
# Model Number: 181 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 181: VECM
# Model Number: 182 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 182: SeasonalityMotif
# Model Number: 183 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 183: SectionalMotif
# Model Number: 184 with model SeasonalNaive in generation 0 of 10
# Model Number: 185 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation fmax which has no identity') in model 185: SectionalMotif
# Model Number: 186 with model SeasonalNaive in generation 0 of 10
# Model Number: 187 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=2) out of bounds (1)') in model 187: SeasonalityMotif
# Model Number: 188 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 188: GLM
# Model Number: 189 with model UnobservedComponents in generation 0 of 10
# Model Number: 190 with model SeasonalityMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 190: SeasonalityMotif
# Model Number: 191 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 191: MultivariateMotif
# Model Number: 192 with model Theta in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 192: Theta
# Model Number: 193 with model SeasonalNaive in generation 0 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# D:\Anaconda3\envs\sd_env\lib\site-packages\numpy\core\_methods.py:182: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# New Generation: 1 of 10
# Model Number: 194 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 194: UnobservedComponents
# Model Number: 195 with model UnobservedComponents in generation 1 of 10
# Model Number: 196 with model UnobservedComponents in generation 1 of 10
# Model Number: 197 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 197: UnobservedComponents
# Model Number: 198 with model UnobservedComponents in generation 1 of 10
# Model Number: 199 with model NVAR in generation 1 of 10
# Model Number: 200 with model NVAR in generation 1 of 10
# Model Number: 201 with model NVAR in generation 1 of 10
# Model Number: 202 with model NVAR in generation 1 of 10
# Model Number: 203 with model NVAR in generation 1 of 10
# Model Number: 204 with model NVAR in generation 1 of 10
# Model Number: 205 with model ARDL in generation 1 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 205: ARDL
# Model Number: 206 with model ARDL in generation 1 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 206: ARDL
# Model Number: 207 with model ARDL in generation 1 of 10
# Template Eval Error: Exception('Transformer STLFilter failed on fit') in model 207: ARDL
# Model Number: 208 with model DatepartRegression in generation 1 of 10
# Model Number: 209 with model DatepartRegression in generation 1 of 10
# Model Number: 210 with model DatepartRegression in generation 1 of 10
# Model Number: 211 with model ConstantNaive in generation 1 of 10
# Model Number: 212 with model ConstantNaive in generation 1 of 10
# Model Number: 213 with model ConstantNaive in generation 1 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 214 with model UnivariateRegression in generation 1 of 10
# Model Number: 215 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer SinTrend failed on fit') in model 215: UnivariateRegression
# Model Number: 216 with model UnivariateRegression in generation 1 of 10
# Model Number: 217 with model NVAR in generation 1 of 10
# Model Number: 218 with model NVAR in generation 1 of 10
# Model Number: 219 with model NVAR in generation 1 of 10
# Model Number: 220 with model UnobservedComponents in generation 1 of 10
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in true_divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 221 with model UnobservedComponents in generation 1 of 10
# ...
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# 72 - AverageValueNaive with avg smape 102.38:
# Model Number: 73 of 154 with model GLS for Validation 2
# 73 - GLS with avg smape 86.43:
# Model Number: 74 of 154 with model AverageValueNaive for Validation 2
# 74 - AverageValueNaive with avg smape 102.38:
# Model Number: 75 of 154 with model ARDL for Validation 2
# Template Eval Error: ValueError('maxlag should be < nobs') in model 75: ARDL
# Model Number: 76 of 154 with model ARDL for Validation 2
# Template Eval Error: ValueError('The number of regressors (4) including deterministics, lags of the endog, lags of the exogenous, and fixed regressors is larer than the sample available for estimation (2).') in model 76: ARDL
# Model Number: 77 of 154 with model ARDL for Validation 2
# Template Eval Error: ValueError('The number of regressors (5) including deterministics, lags of the endog, lags of the exogenous, and fixed regressors is larer than the sample available for estimation (2).') in model 77: ARDL
# Model Number: 78 of 154 with model GLS for Validation 2
# 📈 78 - GLS with avg smape 70.66:
# Model Number: 79 of 154 with model DatepartRegression for Validation 2
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\decomposition\_pca.py:501: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 300 out of 300 | elapsed:    0.0s finished
# 79 - DatepartRegression with avg smape 133.54:
# Model Number: 80 of 154 with model GLS for Validation 2
# 80 - GLS with avg smape 70.8:
# Model Number: 81 of 154 with model ETS for Validation 2
# 81 - ETS with avg smape 102.38:
# Model Number: 82 of 154 with model GLS for Validation 2
# 82 - GLS with avg smape 102.38:
# Model Number: 83 of 154 with model ETS for Validation 2
# 83 - ETS with avg smape 102.38:
# Model Number: 84 of 154 with model GLM for Validation 2
# 84 - GLM with avg smape 102.38:
# Model Number: 85 of 154 with model GLS for Validation 2
# 85 - GLS with avg smape 102.38:
# Model Number: 86 of 154 with model GLS for Validation 2
# 86 - GLS with avg smape 102.38:
# Model Number: 87 of 154 with model GLS for Validation 2
# 87 - GLS with avg smape 102.38:
# Model Number: 88 of 154 with model GLS for Validation 2
# 88 - GLS with avg smape 102.38:
# Model Number: 89 of 154 with model GLS for Validation 2
# 89 - GLS with avg smape 102.38:
# Model Number: 90 of 154 with model ETS for Validation 2
# 90 - ETS with avg smape 102.38:
# Model Number: 91 of 154 with model ETS for Validation 2
# 91 - ETS with avg smape 102.38:
# Model Number: 92 of 154 with model ETS for Validation 2
# 92 - ETS with avg smape 102.38:
# Model Number: 93 of 154 with model ETS for Validation 2
# 93 - ETS with avg smape 102.38:
# Model Number: 94 of 154 with model GLM for Validation 2
# 94 - GLM with avg smape 102.38:
# Model Number: 95 of 154 with model ETS for Validation 2
# 95 - ETS with avg smape 102.38:
# Model Number: 96 of 154 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 96: WindowRegression
# Model Number: 97 of 154 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 97: WindowRegression
# Model Number: 98 of 154 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 98: WindowRegression
# Model Number: 99 of 154 with model GLM for Validation 2
# 99 - GLM with avg smape 133.54:
# Model Number: 100 of 154 with model GLM for Validation 2
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1582: RuntimeWarning: invalid value encountered in log
#   endog * np.log(endog / mu) + (mu - endog))
# 100 - GLM with avg smape 133.54:
# Model Number: 101 of 154 with model GLM for Validation 2
# 101 - GLM with avg smape 133.54:
# Model Number: 102 of 154 with model Theta for Validation 2
# 102 - Theta with avg smape 100.86:
# Model Number: 103 of 154 with model Theta for Validation 2
# 103 - Theta with avg smape 102.38:
# Model Number: 104 of 154 with model Theta for Validation 2
# 104 - Theta with avg smape 100.85:
# Model Number: 105 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 105: NVAR
# Model Number: 106 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 106: NVAR
# Model Number: 107 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 107: NVAR
# Model Number: 108 of 154 with model AverageValueNaive for Validation 2
# 108 - AverageValueNaive with avg smape 102.39:
# Model Number: 109 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 109: NVAR
# Model Number: 110 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 110: NVAR
# Model Number: 111 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 111: NVAR
# Model Number: 112 of 154 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 112: NVAR
# Model Number: 113 of 154 with model ConstantNaive for Validation 2
# 113 - ConstantNaive with avg smape 100.96:
# Model Number: 114 of 154 with model ConstantNaive for Validation 2
# 114 - ConstantNaive with avg smape 102.38:
# Model Number: 115 of 154 with model AverageValueNaive for Validation 2
# 115 - AverageValueNaive with avg smape 102.38:
# Model Number: 116 of 154 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Exception encountered when calling layer "conv1d" (type Conv1D).\n\nNegative dimension size caused by subtracting 1 from 0 for \'{{node conv1d/Conv1D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](conv1d/Conv1D/ExpandDims, conv1d/Conv1D/ExpandDims_1)\' with input shapes: [?,1,0,1], [1,1,1,4].\n\nCall arguments received by layer "conv1d" (type Conv1D):\n  • inputs=tf.Tensor(shape=(None, 0, 1), dtype=float32)') in model 116: WindowRegression
# Model Number: 117 of 154 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 117: WindowRegression
# Model Number: 118 of 154 with model Theta for Validation 2
# 118 - Theta with avg smape 88.26:
# Model Number: 119 of 154 with model Theta for Validation 2
# 119 - Theta with avg smape 100.07:
# Model Number: 120 of 154 with model GLM for Validation 2
# 120 - GLM with avg smape 132.03:
# Model Number: 121 of 154 with model ConstantNaive for Validation 2
# 121 - ConstantNaive with avg smape 102.36:
# Model Number: 122 of 154 with model ConstantNaive for Validation 2
# 122 - ConstantNaive with avg smape 102.38:
# Model Number: 123 of 154 with model ConstantNaive for Validation 2
# 123 - ConstantNaive with avg smape 102.38:
# Model Number: 124 of 154 with model ConstantNaive for Validation 2
# 124 - ConstantNaive with avg smape 102.38:
# Model Number: 125 of 154 with model ConstantNaive for Validation 2
# 125 - ConstantNaive with avg smape 102.38:
# Model Number: 126 of 154 with model ConstantNaive for Validation 2
# 126 - ConstantNaive with avg smape 102.38:
# Model Number: 127 of 154 with model ConstantNaive for Validation 2
# 127 - ConstantNaive with avg smape 102.38:
# Model Number: 128 of 154 with model Theta for Validation 2
# 128 - Theta with avg smape 102.4:
# Model Number: 129 of 154 with model Theta for Validation 2
# 129 - Theta with avg smape 102.4:
# Model Number: 130 of 154 with model Theta for Validation 2
# 130 - Theta with avg smape 102.4:
# Model Number: 131 of 154 with model Theta for Validation 2
# 131 - Theta with avg smape 102.4:
# Model Number: 132 of 154 with model ARIMA for Validation 2
# 132 - ARIMA with avg smape 104.88:
# Model Number: 133 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 133: UnivariateRegression
# Model Number: 134 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: Exception('Transformer SinTrend failed on fit') in model 134: UnivariateRegression
# Model Number: 135 of 154 with model GLM for Validation 2
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 135: GLM
# Model Number: 136 of 154 with model GLM for Validation 2
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 136: GLM
# Model Number: 137 of 154 with model ARIMA for Validation 2
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:426: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# 137 - ARIMA with avg smape 104.43:
# Model Number: 138 of 154 with model ARIMA for Validation 2
# 138 - ARIMA with avg smape 104.43:
# Model Number: 139 of 154 with model ARIMA for Validation 2
# 139 - ARIMA with avg smape 100.58:
# Model Number: 140 of 154 with model GLM for Validation 2
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 140: GLM
# Model Number: 141 of 154 with model ARIMA for Validation 2
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1582: RuntimeWarning: invalid value encountered in log
#   endog * np.log(endog / mu) + (mu - endog))
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\links.py:516: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1582: RuntimeWarning: divide by zero encountered in log
#   endog * np.log(endog / mu) + (mu - endog))
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:1582: RuntimeWarning: invalid value encountered in add
#   endog * np.log(endog / mu) + (mu - endog))
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\generalized_linear_model.py:804: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid / self.family.variance(mu)) / self.df_resid
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\families\family.py:132: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# D:\Anaconda3\envs\sd_env\lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1212: RuntimeWarning: invalid value encountered in multiply
#   - self._offset_exposure)
# 141 - ARIMA with avg smape 107.32:
# Model Number: 142 of 154 with model ARIMA for Validation 2
# 142 - ARIMA with avg smape 107.34:
# Model Number: 143 of 154 with model ARIMA for Validation 2
# 143 - ARIMA with avg smape 99.16:
# Model Number: 144 of 154 with model ARIMA for Validation 2
# 144 - ARIMA with avg smape 96.41:
# Model Number: 145 of 154 with model ARIMA for Validation 2
# 145 - ARIMA with avg smape 107.38:
# Model Number: 146 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 146: UnivariateRegression
# Model Number: 147 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 147: UnivariateRegression
# Model Number: 148 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 148: UnivariateRegression
# Model Number: 149 of 154 with model SeasonalityMotif for Validation 2
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 149: SeasonalityMotif
# Model Number: 150 of 154 with model MetricMotif for Validation 2
# Template Eval Error: Exception('Transformer SinTrend failed on fit') in model 150: MetricMotif
# Model Number: 151 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 151: UnivariateRegression
# Model Number: 152 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 152: UnivariateRegression
# Model Number: 153 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 153: UnivariateRegression
# Model Number: 154 of 154 with model UnivariateRegression for Validation 2
# Template Eval Error: IndexError('index 0 is out of bounds for axis 0 with size 0') in model 154: UnivariateRegression
# Validation Round: 3
# D:\Anaconda3\envs\sd_env\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42272\4285350017.py in <module>
#       1 from autots import AutoTS
#       2 model = AutoTS(forecast_length=4, frequency='infer', ensemble='simple')
# ----> 3 model = model.fit(data, date_col='period_end', value_col='followers_gained', id_col=None)
#       4 prediction = model.predict()
#       5 forecast = prediction.forecast
#
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\evaluator\auto_ts.py in fit(self, df, date_col, value_col, id_col, future_regressor, weights, result_file, grouping_ids, validation_indexes)
#    1277                     forecast_length=forecast_length,
#    1278                     min_allowed_train_percent=self.min_allowed_train_percent,
# -> 1279                     verbose=self.verbose,
#    1280                 )
#    1281                 self.validation_train_indexes.append(val_df_train.index)
#
# D:\Anaconda3\envs\sd_env\lib\site-packages\autots\tools\shaping.py in simple_train_test_split(df, forecast_length, min_allowed_train_percent, verbose)
#     378     ):
#     379         raise ValueError(
# --> 380             "forecast_length is too large for training data, alter min_allowed_train_percent to override"
#     381         )
#     382
#
# ValueError: forecast_length is too large for training data, alter min_allowed_train_percent to override
