# %%
# REF https://frhyme.github.io/python-libs/gensim2_fasttext/#when-to-use-fasttext

# %%
import pandas as pd
import numpy as np
import ast
import string
from tqdm import tqdm

from sklearn.pipeline import Pipeline
from sklearn.linear_model import *
from sklearn.model_selection import *
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.naive_bayes import *
from sklearn.metrics import *

from gensim.models import *

# %%
sentences = ["I am a boy", "you are a girl"]*10
sentences = [s.lower().strip().split(" ") for s in sentences]

# %%
# Word2vec Model.
WVmodel = Word2Vec(min_count=1, vector_size=50)
WVmodel.build_vocab(sentences)
WVmodel.train(sentences, total_examples=len(sentences), epochs=300)
# Out:
# (2156, 24000)

# %%
# FastTest Model.
FTmodel = FastText(min_count=1, vector_size=50)  # size => vector_size
FTmodel.build_vocab(sentences)
FTmodel.train(sentences, total_examples=len(sentences), epochs=300)
# Out:
# (2156, 24000)

# %%
# WVmodel, FTmodel 모두 같은 corpus로부터 생성되었기 때문에 vocabulary는 같습니다.
assert set(WVmodel.wv.index_to_key) == set(FTmodel.wv.index_to_key)

# %% [markdown]
# #### out of vocab

# %%
# Infer Vector for Out-Of-Vocabulary
# 현재 vocab에서 가장 유사하다고 생각되어지는 word와 그 유사도. 
out_of_vocabs = ['boys', 'girls', 'your', 'bare']
for oov in out_of_vocabs:
    print(f"Does WVmodel have <{oov}> in vocab?: {oov in WVmodel.wv.key_to_index}")
    try: # Word2vec의 경우 vocab에 없는 word의 경우 vector로 표현해주지 못함.
        print(f"vector of <{oov}> => {WVmodel.wv[oov]}")
    except Exception as e:
        print(f"- Exception: {e}")
#     print("--"*20)        
    print(f"Does FTmodel have <{oov}> in vocab?: {oov in FTmodel.wv.key_to_index }")
    print(f"- vector of <{oov}> => {FTmodel.wv[oov][:2]}")
    most_similar_vocab = [f"{w}: {sim:.2f}" for w, sim in FTmodel.wv.most_similar(positive=[oov])]
    print(f"- {most_similar_vocab}")
#     print("=="*20)  # out of vocab에 대해서 word2vec, FastText의 결과가 다름을 보임.
# Out:
# Does WVmodel have <boys> in vocab?: False
# - Exception: "Key 'boys' not present"
# Does FTmodel have <boys> in vocab?: False
# - vector of <boys> => [0.00119801 0.00336338]
# - ['boy: 0.62', 'girl: 0.49', 'are: 0.40', 'a: 0.39', 'i: 0.30', 'am: 0.28', 'you: 0.28']
# Does WVmodel have <girls> in vocab?: False
# - Exception: "Key 'girls' not present"
# Does FTmodel have <girls> in vocab?: False
# - vector of <girls> => [-0.00148499  0.00092695]
# - ['girl: 0.71', 'i: 0.53', 'are: 0.50', 'a: 0.47', 'you: 0.41', 'boy: 0.34', 'am: 0.34']
# Does WVmodel have <your> in vocab?: False
# - Exception: "Key 'your' not present"
# Does FTmodel have <your> in vocab?: False
# - vector of <your> => [-0.00329254 -0.00294157]
# - ['girl: 0.48', 'you: 0.44', 'i: 0.27', 'am: 0.27', 'a: 0.23', 'boy: 0.22', 'are: 0.13']
# Does WVmodel have <bare> in vocab?: False
# - Exception: "Key 'bare' not present"
# Does FTmodel have <bare> in vocab?: False
# - vector of <bare> => [ 0.00242721 -0.00344649]
# - ['boy: 0.33', 'girl: 0.32', 'a: 0.30', 'am: 0.28', 'are: 0.26', 'you: 0.21', 'i: 0.17']

# %%
out_of_vocabs = ['hi']
for oov in out_of_vocabs:
    print(f"Does FTmodel have <{oov}> in vocab?: {oov in FTmodel.wv.key_to_index}")
    print(f"- vector of <{oov}> => {FTmodel.wv[oov][:2]}")
    most_similar_vocab = [f"{w}: {sim:.2f}" for w, sim in FTmodel.wv.most_similar(positive=[oov])]
    print(f"- {most_similar_vocab}")
#     print("=="*20)
# Out:
# Does FTmodel have <hi> in vocab?: False
# - vector of <hi> => [ 0.00193439 -0.00188542]
# - ['are: 0.08', 'a: 0.05', 'boy: 0.01', 'i: 0.01', 'am: -0.01', 'girl: -0.06', 'you: -0.06']

# %% [markdown]
# #### in vocab

# %%
sentences = ["I am a boy", "you are a girl"]*100 
sentences.append("we are boys")  # "boys" 빈도 +1 = rare word, almost oov
sentences = [s.lower().strip().split(" ") for s in sentences]

# %%
# Word2vec Model.
WVmodel = Word2Vec(min_count=1, vector_size=50)
WVmodel.build_vocab(sentences)
WVmodel.train(sentences, total_examples=len(sentences), epochs=30)
# Out:
# (2183, 24090)

# %%
FTmodel = FastText(min_count=1, vector_size=50)
FTmodel.build_vocab(sentences)
FTmodel.train(sentences, total_examples=len(sentences), epochs=30)
# Out:
# (2183, 24090)

# %%
assert set(WVmodel.wv.index_to_key) == set(FTmodel.wv.index_to_key)

# %%
print(f"Word2vec similarity: {WVmodel.wv.similarity('boy', 'boys'):.4f}")
print(f"FastText similarity: {FTmodel.wv.similarity('boy', 'boys'):.4f}")
# Out:
# Word2vec similarity: 0.4560
# FastText similarity: 0.8681

# %%
# REF https://radimrehurek.com/gensim/auto_examples/tutorials/run_fasttext.html#sphx-glr-auto-examples-tutorials-run-fasttext-py

# %%
from pprint import pprint as print
from gensim.models.fasttext import FastText
from gensim.test.utils import datapath

# %%
# Set file names for train and test data
corpus_file = datapath('lee_background.cor')

model = FastText(vector_size=100)

# build the vocabulary
model.build_vocab(corpus_file=corpus_file)

# train the model
model.train(
    corpus_file=corpus_file, epochs=model.epochs,
    total_examples=model.corpus_count, total_words=model.corpus_total_words,
)

print(model)
# Out:
# <gensim.models.fasttext.FastText object at 0x000001CEDB60BD48>

# %%
print(corpus_file)
# Out:
# 'D:\\Anaconda3\\envs\\sd_env\\lib\\site-packages\\gensim\\test\\test_data\\lee_background.cor'

# %%
wv = model.wv
print(wv)

#
# FastText models support vector lookups for out-of-vocabulary words by summing up character ngrams belonging to the word.
#
print('night' in wv.key_to_index)
# Out:
# <gensim.models.fasttext.FastTextKeyedVectors object at 0x000001CEDB60BF48>
# True

# %%
wv.key_to_index
# Out:
# {'the': 0,
#  'to': 1,
#  'of': 2,
#  'in': 3,
#  'and': 4,
#  'a': 5,
#  'is': 6,
#  'for': 7,
#  'The': 8,
#  'on': 9,
#  'he': 10,
#  'has': 11,
#  'says': 12,
#  'was': 13,
#  'have': 14,
#  'that': 15,
#  'be': 16,
#  'are': 17,
#  'will': 18,
#  'with': 19,
#  'Mr': 20,
#  'said.': 21,
#  'at': 22,
#  'from': 23,
#  'by': 24,
#  'been': 25,
#  'not': 26,
#  'as': 27,
#  'his': 28,
#  'an': 29,
#  'it': 30,
#  'were': 31,
#  'had': 32,
#  'after': 33,
#  'but': 34,
#  'they': 35,
#  'said': 36,
#  'who': 37,
#  'this': 38,
#  'Australian': 39,
#  'we': 40,
#  'Palestinian': 41,
#  'their': 42,
#  'which': 43,
#  'people': 44,
#  'two': 45,
#  'there': 46,
#  'up': 47,
#  'about': 48,
#  'also': 49,
#  'its': 50,
#  'out': 51,
#  'South': 52,
#  'into': 53,
#  'would': 54,
#  'US': 55,
#  'when': 56,
#  'against': 57,
#  'first': 58,
#  'New': 59,
#  'more': 60,
#  'last': 61,
#  'I': 62,
#  'He': 63,
#  'A': 64,
#  'Israeli': 65,
#  'Australia': 66,
#  'if': 67,
#  'one': 68,
#  'over': 69,
#  'United': 70,
#  'Government': 71,
#  'or': 72,
#  'than': 73,
#  'no': 74,
#  'all': 75,
#  'could': 76,
#  'three': 77,
#  'before': 78,
#  'told': 79,
#  'say': 80,
#  'new': 81,
#  'some': 82,
#  'any': 83,
#  '"We': 84,
#  'bin': 85,
#  'attacks': 86,
#  'very': 87,
#  'still': 88,
#  'just': 89,
#  'now': 90,
#  'security': 91,
#  'police': 92,
#  '"I': 93,
#  'Arafat': 94,
#  'killed': 95,
#  'our': 96,
#  'them': 97,
#  'being': 98,
#  'forces': 99,
#  'Minister': 100,
#  'States': 101,
#  'But': 102,
#  'fire': 103,
#  'what': 104,
#  'around': 105,
#  'man': 106,
#  'other': 107,
#  'where': 108,
#  'can': 109,
#  'next': 110,
#  'think': 111,
#  'per': 112,
#  'day': 113,
#  'company': 114,
#  'four': 115,
#  'Al': 116,
#  'It': 117,
#  '"The': 118,
#  'Qaeda': 119,
#  'you': 120,
#  'take': 121,
#  'officials': 122,
#  'suicide': 123,
#  'so': 124,
#  'President': 125,
#  'Afghan': 126,
#  'under': 127,
#  'Federal': 128,
#  'In': 129,
#  'Laden': 130,
#  'time': 131,
#  'number': 132,
#  'made': 133,
#  'days': 134,
#  'Taliban': 135,
#  'through': 136,
#  'down': 137,
#  'those': 138,
#  'meeting': 139,
#  'Hamas': 140,
#  'including': 141,
#  'workers': 142,
#  'Sydney': 143,
#  'she': 144,
#  'Gaza': 145,
#  'called': 146,
#  'should': 147,
#  'military': 148,
#  'Test': 149,
#  'second': 150,
#  'cent': 151,
#  'since': 152,
#  'today': 153,
#  'Islamic': 154,
#  'back': 155,
#  'World': 156,
#  'between': 157,
#  'September': 158,
#  'get': 159,
#  'Wales': 160,
#  'because': 161,
#  'members': 162,
#  'while': 163,
#  '-': 164,
#  'further': 165,
#  'going': 166,
#  'near': 167,
#  'world': 168,
#  'Bank': 169,
#  'report': 170,
#  'staff': 171,
#  "Australia's": 172,
#  'local': 173,
#  'former': 174,
#  'end': 175,
#  'hours': 176,
#  'him': 177,
#  'government': 178,
#  'attack': 179,
#  'Israel': 180,
#  'West': 181,
#  'only': 182,
#  'make': 183,
#  'off': 184,
#  'do': 185,
#  'Afghanistan': 186,
#  'claims': 187,
#  'international': 188,
#  'another': 189,
#  'like': 190,
#  'leader': 191,
#  'go': 192,
#  "it's": 193,
#  'many': 194,
#  'spokesman': 195,
#  'given': 196,
#  'expected': 197,
#  'five': 198,
#  'left': 199,
#  'group': 200,
#  'good': 201,
#  'Osama': 202,
#  'looking': 203,
#  'Qantas': 204,
#  'saying': 205,
#  'Tora': 206,
#  'Prime': 207,
#  'during': 208,
#  'put': 209,
#  'work': 210,
#  'know': 211,
#  'air': 212,
#  'way': 213,
#  'these': 214,
#  'action': 215,
#  'Indian': 216,
#  'most': 217,
#  'whether': 218,
#  'support': 219,
#  'set': 220,
#  'found': 221,
#  'national': 222,
#  'Afghanistan.': 223,
#  'died': 224,
#  'years': 225,
#  'come': 226,
#  'metres': 227,
#  'Yasser': 228,
#  'year.': 229,
#  'Foreign': 230,
#  'how': 231,
#  'interim': 232,
#  'six': 233,
#  'power': 234,
#  '11': 235,
#  'terrorist': 236,
#  'team': 237,
#  'arrested': 238,
#  'force': 239,
#  'John': 240,
#  "don't": 241,
#  'trying': 242,
#  'start': 243,
#  'part': 244,
#  'official': 245,
#  'groups': 246,
#  'early': 247,
#  'Bora': 248,
#  'us': 249,
#  'Africa': 250,
#  'several': 251,
#  'week': 252,
#  'authorities': 253,
#  'area': 254,
#  'war': 255,
#  '100': 256,
#  '50': 257,
#  'believe': 258,
#  'third': 259,
#  'troops': 260,
#  'Meanwhile,': 261,
#  'yesterday': 262,
#  'best': 263,
#  'Defence': 264,
#  'want': 265,
#  'areas': 266,
#  'militants': 267,
#  'peace': 268,
#  'eight': 269,
#  'need': 270,
#  'Minister,': 271,
#  'leaders': 272,
#  'does': 273,
#  "Arafat's": 274,
#  'following': 275,
#  'match': 276,
#  'weather': 277,
#  'Dr': 278,
#  'few': 279,
#  'state': 280,
#  'confirmed': 281,
#  '12': 282,
#  'came': 283,
#  'Sharon': 284,
#  'close': 285,
#  'reports': 286,
#  'Christmas': 287,
#  'agreement': 288,
#  'must': 289,
#  'help': 290,
#  'Pakistan': 291,
#  'fighters': 292,
#  'months': 293,
#  'brought': 294,
#  'did': 295,
#  'then': 296,
#  'They': 297,
#  'better': 298,
#  'took': 299,
#  'hit': 300,
#  'believed': 301,
#  'Peter': 302,
#  'pay': 303,
#  'pressure': 304,
#  'city': 305,
#  'East': 306,
#  'taken': 307,
#  '10': 308,
#  'south': 309,
#  'maintenance': 310,
#  'asylum': 311,
#  'earlier': 312,
#  'Northern': 313,
#  'lot': 314,
#  'held': 315,
#  'got': 316,
#  'British': 317,
#  'accused': 318,
#  'cut': 319,
#  'much': 320,
#  'senior': 321,
#  'without': 322,
#  'Melbourne': 323,
#  'talks': 324,
#  'injured': 325,
#  'her': 326,
#  'well': 327,
#  'both': 328,
#  'children': 329,
#  'too': 330,
#  'won': 331,
#  'family': 332,
#  'Labor': 333,
#  'Royal': 334,
#  "that's": 335,
#  'shot': 336,
#  'such': 337,
#  'see': 338,
#  'armed': 339,
#  'court': 340,
#  'across': 341,
#  'working': 342,
#  'economy': 343,
#  'lead': 344,
#  'There': 345,
#  'David': 346,
#  'asked': 347,
#  'year': 348,
#  'key': 349,
#  'call': 350,
#  'north': 351,
#  'Union': 352,
#  'change': 353,
#  'statement': 354,
#  'Commission': 355,
#  'arrest': 356,
#  'past': 357,
#  'even': 358,
#  'place': 359,
#  'night': 360,
#  'information': 361,
#  'continuing': 362,
#  'commission': 363,
#  'play': 364,
#  'public': 365,
#  'return': 366,
#  'despite': 367,
#  'Authority': 368,
#  'fighting': 369,
#  'released': 370,
#  'morning': 371,
#  'At': 372,
#  'December': 373,
#  'used': 374,
#  'Waugh': 375,
#  'economic': 376,
#  'captured': 377,
#  'possible': 378,
#  'Police': 379,
#  'leading': 380,
#  'crew': 381,
#  'George': 382,
#  'An': 383,
#  'southern': 384,
#  'major': 385,
#  'least': 386,
#  'Bush': 387,
#  'Pentagon': 388,
#  'Afghanistan,': 389,
#  'unions': 390,
#  'damage': 391,
#  'your': 392,
#  'detainees': 393,
#  'large': 394,
#  'use': 395,
#  'within': 396,
#  'head': 397,
#  'winds': 398,
#  'Hill': 399,
#  'win': 400,
#  'stop': 401,
#  'fires': 402,
#  'give': 403,
#  'final': 404,
#  'million': 405,
#  'eastern': 406,
#  'received': 407,
#  'legal': 408,
#  'far': 409,
#  'Two': 410,
#  'India': 411,
#  'Queensland': 412,
#  'charged': 413,
#  'child': 414,
#  'high': 415,
#  'able': 416,
#  '"If': 417,
#  'American': 418,
#  'Williams': 419,
#  'known': 420,
#  'director': 421,
#  'Australians': 422,
#  'behind': 423,
#  'may': 424,
#  'dead': 425,
#  'services': 426,
#  'already': 427,
#  'Lee': 428,
#  'soldiers': 429,
#  'heard': 430,
#  'might': 431,
#  'process': 432,
#  'remain': 433,
#  'board': 434,
#  'seen': 435,
#  'radio': 436,
#  'taking': 437,
#  'Cup': 438,
#  'forced': 439,
#  'training': 440,
#  '15': 441,
#  'same': 442,
#  'towards': 443,
#  'centre': 444,
#  'water': 445,
#  'latest': 446,
#  'morning.': 447,
#  'Centre': 448,
#  'cricket': 449,
#  'conditions': 450,
#  "there's": 451,
#  'interest': 452,
#  'role': 453,
#  '"It': 454,
#  'long': 455,
#  'failed': 456,
#  'Palestinians': 457,
#  'canyoning': 458,
#  'ago': 459,
#  'storm': 460,
#  'thought': 461,
#  'rates': 462,
#  'York': 463,
#  'news': 464,
#  'strong': 465,
#  'However,': 466,
#  'Australia,': 467,
#  'half': 468,
#  'position': 469,
#  'bowler': 470,
#  'later': 471,
#  'army': 472,
#  'due': 473,
#  'aircraft': 474,
#  'today.': 475,
#  'administration': 476,
#  "I'm": 477,
#  'violence': 478,
#  'Alliance': 479,
#  'control': 480,
#  'strikes': 481,
#  'series': 482,
#  'After': 483,
#  'great': 484,
#  'likely': 485,
#  'offer': 486,
#  'Shane': 487,
#  'Adelaide': 488,
#  'continue': 489,
#  'Ms': 490,
#  'hospital': 491,
#  'concerned': 492,
#  'Kandahar': 493,
#  'Trade': 494,
#  'claimed': 495,
#  'right': 496,
#  'matter': 497,
#  'Downer': 498,
#  'special': 499,
#  'along': 500,
#  'Nations': 501,
#  'African': 502,
#  'month': 503,
#  'campaign': 504,
#  'decision': 505,
#  'buildings': 506,
#  'envoy': 507,
#  'own': 508,
#  'chief': 509,
#  'death': 510,
#  'Blue': 511,
#  'Adventure': 512,
#  'men': 513,
#  'launched': 514,
#  'move': 515,
#  'officers': 516,
#  'guilty': 517,
#  'flight': 518,
#  'firefighters': 519,
#  'line': 520,
#  'rate': 521,
#  'boat': 522,
#  'industrial': 523,
#  'homes': 524,
#  'west': 525,
#  'Swiss': 526,
#  'risk': 527,
#  'show': 528,
#  'plans': 529,
#  'town': 530,
#  'me': 531,
#  'Australia.': 532,
#  'National': 533,
#  'Middle': 534,
#  'using': 535,
#  'weapons': 536,
#  'helicopters': 537,
#  'station': 538,
#  'today,': 539,
#  'northern': 540,
#  'Service': 541,
#  'bus': 542,
#  'operations': 543,
#  'probably': 544,
#  'Mark': 545,
#  'find': 546,
#  'carrying': 547,
#  'Zealand': 548,
#  '14': 549,
#  'really': 550,
#  'others': 551,
#  'life': 552,
#  'important': 553,
#  'captain': 554,
#  'network': 555,
#  'defence': 556,
#  'wants': 557,
#  '"He': 558,
#  'sure': 559,
#  'event': 560,
#  "Laden's": 561,
#  'carried': 562,
#  'Hollingworth': 563,
#  'Industrial': 564,
#  'union': 565,
#  'my': 566,
#  'jobs': 567,
#  'Sydney,': 568,
#  '1999': 569,
#  'health': 570,
#  'General': 571,
#  'International': 572,
#  'UN': 573,
#  'planning': 574,
#  'Zinni': 575,
#  'enough': 576,
#  'jail': 577,
#  'Bichel': 578,
#  'prepared': 579,
#  'home': 580,
#  'late': 581,
#  'side': 582,
#  'political': 583,
#  'person': 584,
#  'hundreds': 585,
#  'community': 586,
#  'immediately': 587,
#  'every': 588,
#  'tried': 589,
#  'said,': 590,
#  'sent': 591,
#  'McGrath': 592,
#  'allow': 593,
#  '"There': 594,
#  'result': 595,
#  'fight': 596,
#  'hard': 597,
#  'years.': 598,
#  'comes': 599,
#  'Council': 600,
#  'job': 601,
#  'am': 602,
#  'beat': 603,
#  'Secretary': 604,
#  'went': 605,
#  'opening': 606,
#  'caught': 607,
#  'although': 608,
#  'race': 609,
#  'Department': 610,
#  'emergency': 611,
#  'kilometres': 612,
#  'getting': 613,
#  'become': 614,
#  'One': 615,
#  'always': 616,
#  'reported': 617,
#  'drop': 618,
#  'radical': 619,
#  '2': 620,
#  'opened': 621,
#  'plane': 622,
#  'calls': 623,
#  'Jihad': 624,
#  'raids': 625,
#  'HIH': 626,
#  'seekers': 627,
#  'issue': 628,
#  'policy': 629,
#  'Relations': 630,
#  'deal': 631,
#  'Israelis': 632,
#  'deaths': 633,
#  'allegations': 634,
#  'each': 635,
#  'evidence': 636,
#  'different': 637,
#  'Security': 638,
#  'building': 639,
#  'growth': 640,
#  'suspected': 641,
#  'Unions': 642,
#  'Woomera': 643,
#  '"It\'s': 644,
#  'laws': 645,
#  'bombing': 646,
#  'alleged': 647,
#  'abuse': 648,
#  'bombings': 649,
#  'financial': 650,
#  'Fire': 651,
#  'Ariel': 652,
#  'proposed': 653,
#  'rejected': 654,
#  'making': 655,
#  'opposition': 656,
#  'full': 657,
#  'Senator': 658,
#  'warplanes': 659,
#  'until': 660,
#  'details': 661,
#  'militant': 662,
#  'Strip': 663,
#  'days.': 664,
#  'Immigration': 665,
#  'airline': 666,
#  'try': 667,
#  'running': 668,
#  'clear': 669,
#  '20': 670,
#  'Commonwealth': 671,
#  'river': 672,
#  'flights': 673,
#  'Alexander': 674,
#  'Parliament': 675,
#  "we're": 676,
#  'young': 677,
#  'currently': 678,
#  'declared': 679,
#  'weekend': 680,
#  'based': 681,
#  'Howard': 682,
#  'human': 683,
#  'executive': 684,
#  'understand': 685,
#  'source': 686,
#  'here': 687,
#  'bid': 688,
#  'caves': 689,
#  'reached': 690,
#  'believes': 691,
#  'State': 692,
#  'yet': 693,
#  'ago.': 694,
#  'innings': 695,
#  '18': 696,
#  'year,': 697,
#  'look': 698,
#  'killing': 699,
#  '"We\'re': 700,
#  'surrender': 701,
#  'time.': 702,
#  'quite': 703,
#  'Britain': 704,
#  'travel': 705,
#  'Jewish': 706,
#  'targets': 707,
#  'Bureau': 708,
#  'access': 709,
#  'meet': 710,
#  'On': 711,
#  'among': 712,
#  'flying': 713,
#  'himself': 714,
#  'annual': 715,
#  'July': 716,
#  'announced': 717,
#  'actually': 718,
#  "year's": 719,
#  'safety': 720,
#  'leader,': 721,
#  'point': 722,
#  'something': 723,
#  'Opposition': 724,
#  'dispute': 725,
#  'Chief': 726,
#  'house': 727,
#  'ended': 728,
#  'weeks': 729,
#  'appeared': 730,
#  'gave': 731,
#  'responsibility': 732,
#  'soon': 733,
#  'step': 734,
#  'More': 735,
#  'Warne': 736,
#  'Mountains': 737,
#  'huge': 738,
#  'night.': 739,
#  'Reserve': 740,
#  "Afghanistan's": 741,
#  'Musharraf': 742,
#  'guides': 743,
#  'face': 744,
#  'overnight': 745,
#  'certainly': 746,
#  'thousands': 747,
#  'means': 748,
#  'caused': 749,
#  'Energy': 750,
#  'gives': 751,
#  'parts': 752,
#  '"What': 753,
#  'figures': 754,
#  'order': 755,
#  "can't": 756,
#  'biggest': 757,
#  'Western': 758,
#  'Test.': 759,
#  'region': 760,
#  'changes': 761,
#  'again': 762,
#  '21': 763,
#  'issues': 764,
#  'seven': 765,
#  'tourists': 766,
#  'times': 767,
#  'ground': 768,
#  'rather': 769,
#  'top': 770,
#  'outside': 771,
#  '13': 772,
#  'people,': 773,
#  'parties': 774,
#  'worst': 775,
#  'wage': 776,
#  'sources': 777,
#  'sex': 778,
#  'decided': 779,
#  '1,000': 780,
#  'whose': 781,
#  'Robert': 782,
#  'Hicks': 783,
#  'bombers': 784,
#  'less': 785,
#  'November': 786,
#  'away': 787,
#  '200': 788,
#  'having': 789,
#  "we've": 790,
#  'cost': 791,
#  'expect': 792,
#  'Kallis': 793,
#  'returned': 794,
#  'investigation': 795,
#  'them.': 796,
#  'victory': 797,
#  'future': 798,
#  'beyond': 799,
#  'Sir': 800,
#  'countries': 801,
#  'ensure': 802,
#  'attempt': 803,
#  'expressed': 804,
#  'terms': 805,
#  'needs': 806,
#  'media': 807,
#  'arrived': 808,
#  'run': 809,
#  'shortly': 810,
#  'Glenn': 811,
#  'break': 812,
#  'refused': 813,
#  'big': 814,
#  'chance': 815,
#  'crash': 816,
#  'calling': 817,
#  'inside': 818,
#  'wave': 819,
#  'beginning': 820,
#  'strike': 821,
#  'Muslim': 822,
#  '"In': 823,
#  'placed': 824,
#  'Detention': 825,
#  'Anthony': 826,
#  'main': 827,
#  'gunmen': 828,
#  'Donald': 829,
#  'Day': 830,
#  'bring': 831,
#  'money': 832,
#  'though': 833,
#  'Boxing': 834,
#  "he's": 835,
#  'party': 836,
#  'massive': 837,
#  'involved': 838,
#  'Safety': 839,
#  'current': 840,
#  'foreign': 841,
#  'Geoff': 842,
#  'Israel,': 843,
#  'border': 844,
#  'bill': 845,
#  'inquiry': 846,
#  'it,': 847,
#  'response': 848,
#  'serious': 849,
#  'She': 850,
#  'sort': 851,
#  "state's": 852,
#  'situation': 853,
#  'Jacques': 854,
#  'overnight.': 855,
#  'morning,': 856,
#  'banks': 857,
#  'River': 858,
#  'forward': 859,
#  'AFP': 860,
#  'Pakistani': 861,
#  'never': 862,
#  'Daryl': 863,
#  'Powell': 864,
#  'ASIO': 865,
#  'witnesses': 866,
#  'Russian': 867,
#  'Brett': 868,
#  'decide': 869,
#  'general': 870,
#  'militia': 871,
#  'protect': 872,
#  '"This': 873,
#  'address': 874,
#  'boy': 875,
#  'available': 876,
#  'according': 877,
#  'attacks.': 878,
#  'warned': 879,
#  'collapse': 880,
#  'cannot': 881,
#  'Monday': 882,
#  'president': 883,
#  'As': 884,
#  'denied': 885,
#  'Anglican': 886,
#  'residents': 887,
#  'Martin': 888,
#  'Governor-General': 889,
#  'struck': 890,
#  'act': 891,
#  'short': 892,
#  'royal': 893,
#  'movement': 894,
#  'Local': 895,
#  'States.': 896,
#  'entered': 897,
#  'lives': 898,
#  'disease': 899,
#  'trees': 900,
#  'cancer': 901,
#  'fact': 902,
#  'level': 903,
#  'mountains': 904,
#  'prevent': 905,
#  'giving': 906,
#  'heavy': 907,
#  'feel': 908,
#  'Kabul': 909,
#  '48': 910,
#  'longer': 911,
#  '"They': 912,
#  'followed': 913,
#  'commanders': 914,
#  'changed': 915,
#  'bomb': 916,
#  'trip': 917,
#  'moved': 918,
#  'offices': 919,
#  'country': 920,
#  '2,000': 921,
#  'well,': 922,
#  'insurance': 923,
#  'fired': 924,
#  'Rural': 925,
#  'total': 926,
#  'front': 927,
#  'coming': 928,
#  'study': 929,
#  'time,': 930,
#  'proposals': 931,
#  'helicopter': 932,
#  'him.': 933,
#  'India.': 934,
#  'Justice': 935,
#  'car': 936,
#  'ever': 937,
#  '5,000': 938,
#  'areas.': 939,
#  'post': 940,
#  'accident': 941,
#  'management': 942,
#  'member': 943,
#  'began': 944,
#  'industry.': 945,
#  'stage': 946,
#  'area.': 947,
#  'hearings': 948,
#  'Pacific': 949,
#  'nearly': 950,
#  'Suharto': 951,
#  'confidence': 952,
#  'share': 953,
#  'ruled': 954,
#  'absolutely': 955,
#  'tour': 956,
#  'threat': 957,
#  'fast': 958,
#  '"These': 959,
#  'hour': 960,
#  'significant': 961,
#  'small': 962,
#  'yacht': 963,
#  'terror': 964,
#  'places': 965,
#  'tanks': 966,
#  'overall': 967,
#  'nine': 968,
#  'Islands': 969,
#  'Hobart': 970,
#  'base': 971,
#  'secretary': 972,
#  'control.': 973,
#  'anything': 974,
#  'tomorrow.': 975,
#  'fighter': 976,
#  'population': 977,
#  'ministers': 978,
#  'French': 979,
#  'Hewitt': 980,
#  'House': 981,
#  'list': 982,
#  'costs': 983,
#  'burning': 984,
#  'confident': 985,
#  'Highway': 986,
#  'rule': 987,
#  'If': 988,
#  'Workers': 989,
#  'accept': 990,
#  'tribal': 991,
#  'White': 992,
#  'quickly': 993,
#  'months.': 994,
#  '"You': 995,
#  'speaking': 996,
#  'global': 997,
#  'survey': 998,
#  'deadly': 999,
#  ...}

# %%
print('nights' in wv.key_to_index)
# Out:
# False

# %%
print(wv['night'])
# Out:
# array([-0.15475433,  0.1252425 , -0.27081397, -0.10889962,  0.04203569,
#         0.37108007,  0.27523392,  0.52786773,  0.28581938, -0.1986254 ,
#         0.03456262, -0.14185578, -0.21298781,  0.5713253 , -0.3888784 ,
#        -0.5917308 ,  0.18881075, -0.2336333 , -0.49938384, -0.567006  ,
#        -0.49670756, -0.01644066, -0.49384695, -0.10753794, -0.12664177,
#        -0.3076506 , -0.666508  , -0.09729929, -0.3132778 ,  0.27637705,
#        -0.3458514 ,  0.31331167,  0.80769545, -0.2884593 ,  0.18809943,
#         0.34015375,  0.3516266 , -0.12963241, -0.42162904, -0.31708774,
#         0.44845504, -0.44526386,  0.03168629, -0.39517945, -0.5213216 ,
#        -0.34871668, -0.08258637,  0.17523675,  0.36536118,  0.0229767 ,
#         0.35191676, -0.50156254,  0.30075848, -0.38963047, -0.17609014,
#        -0.20503609, -0.19204898, -0.20033792,  0.06501315, -0.32075122,
#        -0.32703844, -0.3937584 , -0.15649399,  0.31981346, -0.07401659,
#         0.6701349 ,  0.03683931,  0.07132513,  0.47971678,  0.254163  ,
#        -0.2912825 ,  0.4235699 ,  0.54134196, -0.62769794,  0.30951074,
#        -0.14416917,  0.26049116, -0.01481838,  0.05828157,  0.38371202,
#         0.17948636, -0.4905797 , -0.75281787, -0.10963842, -0.10779531,
#        -0.8545754 ,  0.4796473 ,  0.2131903 , -0.04610693, -0.23703855,
#        -0.01992569,  0.39781225, -0.13912545,  0.02053258, -0.17538418,
#         0.55696315, -0.16290577, -0.24373971,  0.0298063 , -0.25044116],
#       dtype=float32)

# %%
print(wv['nights'])
# Out:
# array([-0.134322  ,  0.10915444, -0.23417717, -0.09382299,  0.03511144,
#         0.31954968,  0.23910838,  0.45785618,  0.24755444, -0.17339875,
#         0.03164794, -0.12100703, -0.18521912,  0.491595  , -0.33745897,
#        -0.5117655 ,  0.1624686 , -0.2013433 , -0.430313  , -0.49060196,
#        -0.42613953, -0.01538588, -0.4266895 , -0.09435295, -0.10810266,
#        -0.26445672, -0.5746753 , -0.08173843, -0.27051112,  0.24022208,
#        -0.29692358,  0.27018812,  0.6961611 , -0.24896628,  0.16269405,
#         0.2934013 ,  0.30509531, -0.11197305, -0.36439785, -0.27455863,
#         0.38682416, -0.38366386,  0.0269192 , -0.34092772, -0.45134073,
#        -0.30012524, -0.06844437,  0.15201978,  0.31714198,  0.02100454,
#         0.30557156, -0.43357727,  0.2605747 , -0.33645216, -0.15178265,
#        -0.1759117 , -0.1676968 , -0.1712804 ,  0.05748541, -0.27453104,
#        -0.2814604 , -0.34052545, -0.13479911,  0.27569476, -0.06336423,
#         0.5800043 ,  0.0320218 ,  0.05910176,  0.41412053,  0.2208367 ,
#        -0.2520161 ,  0.3640799 ,  0.46868864, -0.5421483 ,  0.2689116 ,
#        -0.12360239,  0.22446752, -0.0136257 ,  0.05021139,  0.33146423,
#         0.15567958, -0.42417642, -0.6496966 , -0.09563021, -0.0921551 ,
#        -0.7394618 ,  0.41433036,  0.18433142, -0.03781353, -0.2053692 ,
#        -0.01711548,  0.34260628, -0.12047986,  0.01846135, -0.15194537,
#         0.48147762, -0.14212984, -0.20695531,  0.02588715, -0.21729012],
#       dtype=float32)

# %%
print(wv.similarity("night", "nights"))
# Out:
# 0.999992

# %%
print(wv.most_similar("nights"))
# Out:
# [('night', 0.9999919533729553),
#  ('rights', 0.9999876022338867),
#  ('flights', 0.9999876022338867),
#  ('overnight', 0.999987006187439),
#  ('fighting', 0.9999858140945435),
#  ('entered', 0.9999855160713196),
#  ('fight', 0.9999850988388062),
#  ('fighters', 0.9999850988388062),
#  ('fighter', 0.9999844431877136),
#  ('treated', 0.9999844431877136)]
